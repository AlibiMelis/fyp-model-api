# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import LSTM,Dropout,Dense
from sklearn.preprocessing import MinMaxScaler
import math
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('formatted_expenses.csv')
df = df.drop(['Unnamed: 0'], axis=1)
df
# Out:
#         trans_id  account_id        date  type    amount  last_trans_1  \
# 0            201           1  1995-06-22     1    72.000        72.000
# 1            202           1  1995-07-22     1  1908.000      1908.000
# 2            203           1  1995-08-21     1  2700.000      2700.000
# 3            159           1  1995-08-31     1     5.256         5.256
# 4             58           1  1995-09-05     1   882.720       882.720
# ...          ...         ...         ...   ...       ...           ...
# 139368    307078        1047  1998-11-23     1   475.200       475.200
# 139369    307138        1047  1998-11-30     1     5.256         5.256
# 139370    307020        1047  1998-12-05     1  1562.040      1562.040
# 139371    307030        1047  1998-12-08     1   576.000       576.000
# 139372    307077        1047  1998-12-08     1   820.800       820.800
#
#         last_trans_2  last_trans_3  last_trans_4  last_trans_5  ...  \
# 0                NaN           NaN           NaN           NaN  ...
# 1             72.000           NaN           NaN           NaN  ...
# 2           1908.000        72.000           NaN           NaN  ...
# 3           2700.000      1908.000        72.000           NaN  ...
# 4              5.256      2700.000      1908.000        72.000  ...
# ...              ...           ...           ...           ...  ...
# 139368      1562.040         5.256      1562.040       216.000  ...
# 139369       475.200      1562.040         5.256      1562.040  ...
# 139370         5.256       475.200      1562.040         5.256  ...
# 139371      1562.040         5.256       475.200      1562.040  ...
# 139372       576.000      1562.040         5.256       475.200  ...
#
#         last_trans_11  last_trans_12  last_trans_13  last_trans_14  \
# 0                 NaN            NaN            NaN            NaN
# 1                 NaN            NaN            NaN            NaN
# 2                 NaN            NaN            NaN            NaN
# 3                 NaN            NaN            NaN            NaN
# 4                 NaN            NaN            NaN            NaN
# ...               ...            ...            ...            ...
# 139368       1562.040          5.256       2534.400       1562.040
# 139369          5.256       1562.040          5.256       2534.400
# 139370       1562.040          5.256       1562.040          5.256
# 139371          5.256       1562.040          5.256       1562.040
# 139372       1562.040          5.256       1562.040          5.256
#
#         last_trans_15  last_trans_16  last_trans_17  last_trans_18  \
# 0                 NaN            NaN            NaN            NaN
# 1                 NaN            NaN            NaN            NaN
# 2                 NaN            NaN            NaN            NaN
# 3                 NaN            NaN            NaN            NaN
# 4                 NaN            NaN            NaN            NaN
# ...               ...            ...            ...            ...
# 139368          5.256       1562.040        432.000          5.256
# 139369       1562.040          5.256       1562.040        432.000
# 139370       2534.400       1562.040          5.256       1562.040
# 139371          5.256       2534.400       1562.040          5.256
# 139372       1562.040          5.256       2534.400       1562.040
#
#         last_trans_19  last_trans_20
# 0                 NaN            NaN
# 1                 NaN            NaN
# 2                 NaN            NaN
# 3                 NaN            NaN
# 4                 NaN            NaN
# ...               ...            ...
# 139368       1562.040          5.256
# 139369          5.256       1562.040
# 139370        432.000          5.256
# 139371       1562.040        432.000
# 139372          5.256       1562.040
#
# [139373 rows x 25 columns]

# %%
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
df['weekday'] = df['date'].dt.dayofweek
df['day'] = df['date'].dt.day
df['month'] = df['date'].dt.month
df['year'] = df['date'].dt.year

# %%
df['account_id'].value_counts()
# Out:
# 96      479
# 866     476
# 655     467
# 396     456
# 1006    435
#        ...
# 672       5
# 758       4
# 315       4
# 182       3
# 727       2
# Name: account_id, Length: 1000, dtype: int64

# %%
single_user_data = df[df['account_id']==96].fillna(0).drop(['date'],axis=1).reset_index()

split = int(len(single_user_data) * 0.8)
train = single_user_data[:split]
test = single_user_data[split:]

scaler = MinMaxScaler(feature_range=(0, 1))
x_t = train.drop(['amount', 'trans_id'], axis=1)
y_t = pd.DataFrame(train['amount'])
x_s = test.drop(['amount', 'trans_id'], axis=1)
y_s = pd.DataFrame(test['amount'])

x_train = scaler.fit_transform(x_t)
y_train = scaler.fit_transform(y_t)

x_test = scaler.fit_transform(x_s)
y_test = scaler.fit_transform(y_s)

single_user_data

# x_train = train.drop(['amount', 'trans_id'], axis=1)
# y_train = train['amount']
# x_test = test.drop(['amount', 'trans_id'], axis=1)
# y_test = test['amount']
# Out:
#      index  trans_id  account_id  type    amount  last_trans_1  last_trans_2  \
# 0    13177     29727          96     1   4140.00       4140.00          0.00
# 1    13178     29728          96     1   8892.00       8892.00       4140.00
# 2    13179     29729          96     1  12636.00      12636.00       8892.00
# 3    13180     29730          96     1  22644.00      22644.00      12636.00
# 4    13181     29731          96     1   6912.00       6912.00      22644.00
# ..     ...       ...         ...   ...       ...           ...           ...
# 474  13651     29395          96     1    770.40        770.40      21528.00
# 475  13652     29539          96     1    231.84        231.84        770.40
# 476  13653     29323          96     1    326.88        326.88        231.84
# 477  13654     29815          96     1    396.00        396.00        326.88
# 478  13655     29588          96     1   2700.00       2700.00        396.00
#
#      last_trans_3  last_trans_4  last_trans_5  ...  last_trans_15  \
# 0            0.00          0.00         0.000  ...          0.000
# 1            0.00          0.00         0.000  ...          0.000
# 2         4140.00          0.00         0.000  ...          0.000
# 3         8892.00       4140.00         0.000  ...          0.000
# 4        12636.00       8892.00      4140.000  ...          0.000
# ..            ...           ...           ...  ...            ...
# 474       3780.00         16.56         5.256  ...        231.840
# 475      21528.00       3780.00        16.560  ...        770.400
# 476        770.40      21528.00      3780.000  ...        326.880
# 477        231.84        770.40     21528.000  ...       3456.000
# 478        326.88        231.84       770.400  ...          5.256
#
#      last_trans_16  last_trans_17  last_trans_18  last_trans_19  \
# 0             0.00           0.00          0.000          0.000
# 1             0.00           0.00          0.000          0.000
# 2             0.00           0.00          0.000          0.000
# 3             0.00           0.00          0.000          0.000
# 4             0.00           0.00          0.000          0.000
# ..             ...            ...            ...            ...
# 474          16.56        4212.00          5.256       5256.000
# 475         231.84          16.56       4212.000          5.256
# 476         770.40         231.84         16.560       4212.000
# 477         326.88         770.40        231.840         16.560
# 478        3456.00         326.88        770.400        231.840
#
#      last_trans_20  weekday  day  month  year
# 0            0.000        5   20      3  1993
# 1            0.000        0   19      4  1993
# 2            0.000        2   19      5  1993
# 3            0.000        4   11      6  1993
# 4            0.000        4   18      6  1993
# ..             ...      ...  ...    ...   ...
# 474        326.880        4   11     12  1998
# 475       5256.000        4   11     12  1998
# 476          5.256        0   14     12  1998
# 477       4212.000        5   19     12  1998
# 478         16.560        0   21     12  1998
#
# [479 rows x 29 columns]

# %%
x_t.shape, x_train.shape
# Out:
# ((383, 27), (383, 27))

# %%
x_train_np = np.array(x_train)
y_train_np = np.array(y_train)
x_test_np = np.array(x_test)
y_test_np = np.array(y_test)

x_train_np = x_train_np.reshape(x_train_np.shape[0], x_train_np.shape[1], 1)
x_test_np = x_test_np.reshape(x_test_np.shape[0], x_test_np.shape[1], 1)
y_train_np = y_train_np.reshape(y_train_np.shape[0], 1)
y_test_np = y_test_np.reshape(y_test_np.shape[0], 1)

# %%
x_train_np.shape, y_train_np.shape, x_test_np.shape, y_test_np.shape
# Out:
# ((383, 27, 1), (383, 1), (96, 27, 1), (96, 1))

# %%
type(x_train_np), type(y_train_np), type(x_test_np), type(y_test_np)
# Out:
# (numpy.ndarray, numpy.ndarray, numpy.ndarray, numpy.ndarray)

# %%
x_train
# Out:
# array([[0.        , 0.        , 0.        , ..., 0.63333333, 0.18181818,
#         0.        ],
#        [0.0026178 , 0.        , 0.        , ..., 0.6       , 0.27272727,
#         0.        ],
#        [0.0052356 , 0.        , 0.        , ..., 0.6       , 0.36363636,
#         0.        ],
#        ...,
#        [0.9947644 , 0.        , 0.        , ..., 0.43333333, 0.90909091,
#         1.        ],
#        [0.9973822 , 0.        , 0.        , ..., 0.73333333, 0.90909091,
#         1.        ],
#        [1.        , 0.        , 0.        , ..., 0.76666667, 0.90909091,
#         1.        ]])

# %%
plt.figure(figsize=(16, 9))
plt.title('Training data - Expenses over time')
plt.plot(single_user_data['amount'][:split], color='black')
plt.plot(single_user_data['amount'][split:], color='green')
plt.xlabel('Date')
plt.ylabel('Expenses in HK$')
plt.show()

# %%
lstm_model=Sequential()
lstm_model.add(LSTM(units=50,return_sequences=True,input_shape=(x_train_np.shape[1], 1)))
lstm_model.add(LSTM(units=50))
lstm_model.add(Dense(1))
lstm_model.compile(loss='mean_squared_error',optimizer='adam')
lstm_model.summary()
# Out:
# 2023-03-29 22:22:36.943532: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 27, 50)            10400
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 30,651
# Trainable params: 30,651
# Non-trainable params: 0
# _________________________________________________________________

# %%
lstm_model.fit(x_train_np, y_train_np, batch_size=1, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 383/383 [==============================] - 3s 8ms/step - loss: 0.0260
# Epoch 2/100
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0250
# Epoch 3/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0248
# Epoch 4/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0248
# Epoch 5/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0242
# Epoch 6/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0249
# Epoch 7/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0241
# Epoch 8/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0242
# Epoch 9/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0218
# Epoch 10/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0223
# Epoch 11/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0221
# Epoch 12/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0219
# Epoch 13/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0211
# Epoch 14/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0217
# Epoch 15/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0209
# Epoch 16/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0193
# Epoch 17/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0161
# Epoch 18/100
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0162
# Epoch 19/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0123
# Epoch 20/100
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0095
# Epoch 21/100
# 383/383 [==============================] - 3s 8ms/step - loss: 0.0084
# Epoch 22/100
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0065
# Epoch 23/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0052
# Epoch 24/100
# 383/383 [==============================] - 3s 9ms/step - loss: 0.0038
# Epoch 25/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0045
# Epoch 26/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0025
# Epoch 27/100
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0031
# Epoch 28/100
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0040
# Epoch 29/100
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0044
# Epoch 30/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0031
# Epoch 31/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0017
# Epoch 32/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0013
# Epoch 33/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0029
# Epoch 34/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0015
# Epoch 35/100
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0024
# Epoch 36/100
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0208
# Epoch 37/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0083
# Epoch 38/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0019
# Epoch 39/100
# 383/383 [==============================] - 3s 7ms/step - loss: 8.1196e-04
# Epoch 40/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0039
# Epoch 41/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0014
# Epoch 42/100
# 383/383 [==============================] - 3s 7ms/step - loss: 7.6731e-04
# Epoch 43/100
# 383/383 [==============================] - 2s 6ms/step - loss: 6.6038e-04
# Epoch 44/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0011
# Epoch 45/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0027
# Epoch 46/100
# 383/383 [==============================] - 2s 6ms/step - loss: 4.0714e-04
# Epoch 47/100
# 383/383 [==============================] - 2s 6ms/step - loss: 3.9654e-04
# Epoch 48/100
# 383/383 [==============================] - 2s 6ms/step - loss: 8.5655e-04
# Epoch 49/100
# 383/383 [==============================] - 2s 6ms/step - loss: 3.6591e-04
# Epoch 50/100
# 383/383 [==============================] - 3s 7ms/step - loss: 2.5698e-04
# Epoch 51/100
# 383/383 [==============================] - 2s 6ms/step - loss: 3.9643e-04
# Epoch 52/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0012
# Epoch 53/100
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0029
# Epoch 54/100
# 383/383 [==============================] - 2s 6ms/step - loss: 9.5082e-04
# Epoch 55/100
# 383/383 [==============================] - 2s 7ms/step - loss: 3.7475e-04
# Epoch 56/100
# 383/383 [==============================] - 3s 7ms/step - loss: 2.9416e-04
# Epoch 57/100
# 383/383 [==============================] - 3s 7ms/step - loss: 3.3493e-04
# Epoch 58/100
# 383/383 [==============================] - 3s 8ms/step - loss: 1.9645e-04
# Epoch 59/100
# 383/383 [==============================] - 3s 8ms/step - loss: 5.0208e-04
# Epoch 60/100
# 383/383 [==============================] - 3s 9ms/step - loss: 3.0728e-04
# Epoch 61/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0017
# Epoch 62/100
# 383/383 [==============================] - 2s 6ms/step - loss: 4.5443e-04
# Epoch 63/100
# 383/383 [==============================] - 4s 10ms/step - loss: 2.5686e-04
# Epoch 64/100
# 383/383 [==============================] - 2s 6ms/step - loss: 1.5378e-04
# Epoch 65/100
# 383/383 [==============================] - 2s 6ms/step - loss: 2.1966e-04
# Epoch 66/100
# 383/383 [==============================] - 2s 6ms/step - loss: 3.8381e-04
# Epoch 67/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0057
# Epoch 68/100
# 383/383 [==============================] - 2s 6ms/step - loss: 4.9680e-04
# Epoch 69/100
# 383/383 [==============================] - 2s 6ms/step - loss: 2.5155e-04
# Epoch 70/100
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0020
# Epoch 71/100
# 383/383 [==============================] - 3s 7ms/step - loss: 4.2123e-04
# Epoch 72/100
# 383/383 [==============================] - 3s 7ms/step - loss: 2.2357e-04
# Epoch 73/100
# 383/383 [==============================] - 2s 6ms/step - loss: 1.7950e-04
# Epoch 74/100
# 383/383 [==============================] - 2s 6ms/step - loss: 1.5214e-04
# Epoch 75/100
# 383/383 [==============================] - 2s 6ms/step - loss: 2.9147e-04
# Epoch 76/100
# 383/383 [==============================] - 3s 7ms/step - loss: 3.7846e-04
# Epoch 77/100
# 383/383 [==============================] - 3s 7ms/step - loss: 3.0089e-04
# Epoch 78/100
# 383/383 [==============================] - 3s 7ms/step - loss: 2.3035e-04
# Epoch 79/100
# 383/383 [==============================] - 2s 6ms/step - loss: 2.9020e-04
# Epoch 80/100
# 383/383 [==============================] - 2s 6ms/step - loss: 2.8218e-04
# Epoch 81/100
# 383/383 [==============================] - 3s 7ms/step - loss: 4.2648e-04
# Epoch 82/100
# 383/383 [==============================] - 3s 7ms/step - loss: 1.7178e-04
# Epoch 83/100
# 383/383 [==============================] - 2s 7ms/step - loss: 1.1392e-04
# Epoch 84/100
# 383/383 [==============================] - 3s 7ms/step - loss: 1.4189e-04
# Epoch 85/100
# 383/383 [==============================] - 3s 7ms/step - loss: 1.7805e-04
# Epoch 86/100
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0011
# Epoch 87/100
# 383/383 [==============================] - 2s 6ms/step - loss: 2.5630e-04
# Epoch 88/100
# 383/383 [==============================] - 2s 6ms/step - loss: 2.3524e-04
# Epoch 89/100
# 383/383 [==============================] - 2s 6ms/step - loss: 2.8021e-04
# Epoch 90/100
# 383/383 [==============================] - 3s 7ms/step - loss: 8.9371e-05
# Epoch 91/100
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0019
# Epoch 92/100
# 383/383 [==============================] - 3s 7ms/step - loss: 4.4733e-04
# Epoch 93/100
# 383/383 [==============================] - 2s 6ms/step - loss: 1.6643e-04
# Epoch 94/100
# 383/383 [==============================] - 2s 6ms/step - loss: 1.1488e-04
# Epoch 95/100
# 383/383 [==============================] - 3s 7ms/step - loss: 1.2105e-04
# Epoch 96/100
# 383/383 [==============================] - 3s 7ms/step - loss: 9.0629e-05
# Epoch 97/100
# 383/383 [==============================] - 3s 7ms/step - loss: 2.1474e-04
# Epoch 98/100
# 383/383 [==============================] - 3s 7ms/step - loss: 1.5002e-04
# Epoch 99/100
# 383/383 [==============================] - 3s 7ms/step - loss: 1.8677e-04
# Epoch 100/100
# 383/383 [==============================] - 2s 6ms/step - loss: 3.4406e-04

# %%
y_predicted = lstm_model.predict(x_test_np)
print(y_predicted.shape)
y_predicted = scaler.inverse_transform(y_predicted)
# Out:
# (96, 1)

# %%
x_test_

# %%
y_test_transformed = scaler.inverse_transform(y_test_np)
print('Validation Root Mean Square Error (RMSE):', np.sqrt(mean_squared_error(y_test_transformed, y_predicted)))
# Out:
# Validation Root Mean Square Error (RMSE): 223.54986100282346

# %%
validation = actual.filter(['amount'])
validation['Prediction'] = y_predicted
validation
# Out:
#        amount    Prediction
# 0       5.256    189.892258
# 1    2592.000   2398.189697
# 2      16.560    166.473099
# 3   18900.000  19000.312500
# 4     231.840    356.426819
# ..        ...           ...
# 91    770.400    827.817871
# 92    231.840    217.514709
# 93    326.880    360.025848
# 94    396.000    407.506897
# 95   2700.000   2629.192627
#
# [96 rows x 2 columns]

# %%
actual = test.reset_index()
plt.figure(figsize=(16, 9))
plt.title('Testing data - Expenses over time')
plt.plot(actual['amount'], color='black')
plt.plot(y_predicted, color='green')
plt.xlabel('Date')
plt.ylabel('Expenses in HK$')
plt.show()

# %%
test
# Out:
#      index  trans_id  account_id  type     amount  last_trans_1  last_trans_2  \
# 383  13560     29714          96     1      5.256         5.256      7380.000
# 384  13561     29587          96     1   2592.000      2592.000         5.256
# 385  13562     29455          96     1     16.560        16.560      2592.000
# 386  13563     29798          96     1  18900.000     18900.000        16.560
# 387  13564     29527          96     1    231.840       231.840     18900.000
# ..     ...       ...         ...   ...        ...           ...           ...
# 474  13651     29395          96     1    770.400       770.400     21528.000
# 475  13652     29539          96     1    231.840       231.840       770.400
# 476  13653     29323          96     1    326.880       326.880       231.840
# 477  13654     29815          96     1    396.000       396.000       326.880
# 478  13655     29588          96     1   2700.000      2700.000       396.000
#
#      last_trans_3  last_trans_4  last_trans_5  ...  last_trans_15  \
# 383      4104.000       326.880       231.840  ...          5.256
# 384      7380.000      4104.000       326.880  ...         16.560
# 385         5.256      7380.000      4104.000  ...       6408.000
# 386      2592.000         5.256      7380.000  ...        231.840
# 387        16.560      2592.000         5.256  ...        770.400
# ..            ...           ...           ...  ...            ...
# 474      3780.000        16.560         5.256  ...        231.840
# 475     21528.000      3780.000        16.560  ...        770.400
# 476       770.400     21528.000      3780.000  ...        326.880
# 477       231.840       770.400     21528.000  ...       3456.000
# 478       326.880       231.840       770.400  ...          5.256
#
#      last_trans_16  last_trans_17  last_trans_18  last_trans_19  \
# 383       6048.000        326.880        770.400        231.840
# 384          5.256       6048.000        326.880        770.400
# 385         16.560          5.256       6048.000        326.880
# 386       6408.000         16.560          5.256       6048.000
# 387        231.840       6408.000         16.560          5.256
# ..             ...            ...            ...            ...
# 474         16.560       4212.000          5.256       5256.000
# 475        231.840         16.560       4212.000          5.256
# 476        770.400        231.840         16.560       4212.000
# 477        326.880        770.400        231.840         16.560
# 478       3456.000        326.880        770.400        231.840
#
#      last_trans_20  weekday  day  month  year
# 383         16.560        6   30     11  1997
# 384        231.840        2    3     12  1997
# 385        770.400        0    8     12  1997
# 386        326.880        3   11     12  1997
# 387       6048.000        3   11     12  1997
# ..             ...      ...  ...    ...   ...
# 474        326.880        4   11     12  1998
# 475       5256.000        4   11     12  1998
# 476          5.256        0   14     12  1998
# 477       4212.000        5   19     12  1998
# 478         16.560        0   21     12  1998
#
# [96 rows x 29 columns]

# %%
test.iloc[1]
# Out:
# index            13561.000
# trans_id         29587.000
# account_id          96.000
# type                 1.000
# amount            2592.000
# last_trans_1      2592.000
# last_trans_2         5.256
# last_trans_3      7380.000
# last_trans_4      4104.000
# last_trans_5       326.880
# last_trans_6       231.840
# last_trans_7       770.400
# last_trans_8        16.560
# last_trans_9         5.256
# last_trans_10     3636.000
# last_trans_11      326.880
# last_trans_12      770.400
# last_trans_13      231.840
# last_trans_14     6408.000
# last_trans_15       16.560
# last_trans_16        5.256
# last_trans_17     6048.000
# last_trans_18      326.880
# last_trans_19      770.400
# last_trans_20      231.840
# weekday              2.000
# day                  3.000
# month               12.000
# year              1997.000
# Name: 384, dtype: float64

# %%
import joblib

joblib.dump(lstm_model, 'lstm_model.pkl')
lr = joblib.load('lstm_model.pkl')
lstm_columns = list(x_t.columns)
joblib.dump(lstm_columns, 'lstm_columns.pkl')
# Out:
# 2023-03-29 22:37:20.735864: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://99bbd352-c036-4696-a19d-f93a4a035a9a/assets
# INFO:tensorflow:Assets written to: ram://99bbd352-c036-4696-a19d-f93a4a035a9a/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fa5f91c5e80> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fa5dde71640> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# ['lstm_columns.pkl']
