# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import LSTM,Dropout,Dense
from sklearn.preprocessing import MinMaxScaler
import math
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('formatted_expenses.csv')
df = df.drop(['Unnamed: 0'], axis=1)
df
# Out:
#         trans_id  account_id        date  type    amount  last_trans_1  \
# 0            201           1  1995-06-22     1    72.000        72.000
# 1            202           1  1995-07-22     1  1908.000      1908.000
# 2            203           1  1995-08-21     1  2700.000      2700.000
# 3            159           1  1995-08-31     1     5.256         5.256
# 4             58           1  1995-09-05     1   882.720       882.720
# ...          ...         ...         ...   ...       ...           ...
# 139368    307078        1047  1998-11-23     1   475.200       475.200
# 139369    307138        1047  1998-11-30     1     5.256         5.256
# 139370    307020        1047  1998-12-05     1  1562.040      1562.040
# 139371    307030        1047  1998-12-08     1   576.000       576.000
# 139372    307077        1047  1998-12-08     1   820.800       820.800
#
#         last_trans_2  last_trans_3  last_trans_4  last_trans_5  ...  \
# 0                NaN           NaN           NaN           NaN  ...
# 1             72.000           NaN           NaN           NaN  ...
# 2           1908.000        72.000           NaN           NaN  ...
# 3           2700.000      1908.000        72.000           NaN  ...
# 4              5.256      2700.000      1908.000        72.000  ...
# ...              ...           ...           ...           ...  ...
# 139368      1562.040         5.256      1562.040       216.000  ...
# 139369       475.200      1562.040         5.256      1562.040  ...
# 139370         5.256       475.200      1562.040         5.256  ...
# 139371      1562.040         5.256       475.200      1562.040  ...
# 139372       576.000      1562.040         5.256       475.200  ...
#
#         last_trans_11  last_trans_12  last_trans_13  last_trans_14  \
# 0                 NaN            NaN            NaN            NaN
# 1                 NaN            NaN            NaN            NaN
# 2                 NaN            NaN            NaN            NaN
# 3                 NaN            NaN            NaN            NaN
# 4                 NaN            NaN            NaN            NaN
# ...               ...            ...            ...            ...
# 139368       1562.040          5.256       2534.400       1562.040
# 139369          5.256       1562.040          5.256       2534.400
# 139370       1562.040          5.256       1562.040          5.256
# 139371          5.256       1562.040          5.256       1562.040
# 139372       1562.040          5.256       1562.040          5.256
#
#         last_trans_15  last_trans_16  last_trans_17  last_trans_18  \
# 0                 NaN            NaN            NaN            NaN
# 1                 NaN            NaN            NaN            NaN
# 2                 NaN            NaN            NaN            NaN
# 3                 NaN            NaN            NaN            NaN
# 4                 NaN            NaN            NaN            NaN
# ...               ...            ...            ...            ...
# 139368          5.256       1562.040        432.000          5.256
# 139369       1562.040          5.256       1562.040        432.000
# 139370       2534.400       1562.040          5.256       1562.040
# 139371          5.256       2534.400       1562.040          5.256
# 139372       1562.040          5.256       2534.400       1562.040
#
#         last_trans_19  last_trans_20
# 0                 NaN            NaN
# 1                 NaN            NaN
# 2                 NaN            NaN
# 3                 NaN            NaN
# 4                 NaN            NaN
# ...               ...            ...
# 139368       1562.040          5.256
# 139369          5.256       1562.040
# 139370        432.000          5.256
# 139371       1562.040        432.000
# 139372          5.256       1562.040
#
# [139373 rows x 25 columns]

# %%
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
df['weekday'] = df['date'].dt.dayofweek
df['day'] = df['date'].dt.day
df['month'] = df['date'].dt.month
df['year'] = df['date'].dt.year

# %%
df['account_id'].value_counts()
# Out:
# 96      479
# 866     476
# 655     467
# 396     456
# 1006    435
#        ...
# 672       5
# 758       4
# 315       4
# 182       3
# 727       2
# Name: account_id, Length: 1000, dtype: int64

# %%
single_user_data = df[df['account_id']==96].fillna(0).drop(['date', 'last_trans_1'],axis=1).reset_index()
single_user_data = single_user_data.drop(['index'], axis=1)

split = int(len(single_user_data) * 0.8)
train = single_user_data[:split]
test = single_user_data[split:]

scaler = MinMaxScaler(feature_range=(0, 1))
x_t = train.drop(['amount', 'trans_id'], axis=1)
y_t = pd.DataFrame(train['amount'])
x_s = test.drop(['amount', 'trans_id'], axis=1)
y_s = pd.DataFrame(test['amount'])

x_train = scaler.fit_transform(x_t)
y_train = scaler.fit_transform(y_t)

x_test = scaler.fit_transform(x_s)
y_test = scaler.fit_transform(y_s)

single_user_data

# x_train = train.drop(['amount', 'trans_id'], axis=1)
# y_train = train['amount']
# x_test = test.drop(['amount', 'trans_id'], axis=1)
# y_test = test['amount']
# Out:
#      trans_id  account_id  type    amount  last_trans_2  last_trans_3  \
# 0       29727          96     1   4140.00          0.00          0.00
# 1       29728          96     1   8892.00       4140.00          0.00
# 2       29729          96     1  12636.00       8892.00       4140.00
# 3       29730          96     1  22644.00      12636.00       8892.00
# 4       29731          96     1   6912.00      22644.00      12636.00
# ..        ...         ...   ...       ...           ...           ...
# 474     29395          96     1    770.40      21528.00       3780.00
# 475     29539          96     1    231.84        770.40      21528.00
# 476     29323          96     1    326.88        231.84        770.40
# 477     29815          96     1    396.00        326.88        231.84
# 478     29588          96     1   2700.00        396.00        326.88
#
#      last_trans_4  last_trans_5  last_trans_6  last_trans_7  ...  \
# 0            0.00         0.000         0.000         0.000  ...
# 1            0.00         0.000         0.000         0.000  ...
# 2            0.00         0.000         0.000         0.000  ...
# 3         4140.00         0.000         0.000         0.000  ...
# 4         8892.00      4140.000         0.000         0.000  ...
# ..            ...           ...           ...           ...  ...
# 474         16.56         5.256      5832.000       326.880  ...
# 475       3780.00        16.560         5.256      5832.000  ...
# 476      21528.00      3780.000        16.560         5.256  ...
# 477        770.40     21528.000      3780.000        16.560  ...
# 478        231.84       770.400     21528.000      3780.000  ...
#
#      last_trans_15  last_trans_16  last_trans_17  last_trans_18  \
# 0            0.000           0.00           0.00          0.000
# 1            0.000           0.00           0.00          0.000
# 2            0.000           0.00           0.00          0.000
# 3            0.000           0.00           0.00          0.000
# 4            0.000           0.00           0.00          0.000
# ..             ...            ...            ...            ...
# 474        231.840          16.56        4212.00          5.256
# 475        770.400         231.84          16.56       4212.000
# 476        326.880         770.40         231.84         16.560
# 477       3456.000         326.88         770.40        231.840
# 478          5.256        3456.00         326.88        770.400
#
#      last_trans_19  last_trans_20  weekday  day  month  year
# 0            0.000          0.000        5   20      3  1993
# 1            0.000          0.000        0   19      4  1993
# 2            0.000          0.000        2   19      5  1993
# 3            0.000          0.000        4   11      6  1993
# 4            0.000          0.000        4   18      6  1993
# ..             ...            ...      ...  ...    ...   ...
# 474       5256.000        326.880        4   11     12  1998
# 475          5.256       5256.000        4   11     12  1998
# 476       4212.000          5.256        0   14     12  1998
# 477         16.560       4212.000        5   19     12  1998
# 478        231.840         16.560        0   21     12  1998
#
# [479 rows x 27 columns]

# %%
x_t.columns
# Out:
# Index(['account_id', 'type', 'last_trans_2', 'last_trans_3', 'last_trans_4',
#        'last_trans_5', 'last_trans_6', 'last_trans_7', 'last_trans_8',
#        'last_trans_9', 'last_trans_10', 'last_trans_11', 'last_trans_12',
#        'last_trans_13', 'last_trans_14', 'last_trans_15', 'last_trans_16',
#        'last_trans_17', 'last_trans_18', 'last_trans_19', 'last_trans_20',
#        'weekday', 'day', 'month', 'year'],
#       dtype='object')

# %%
x_t.shape, x_train.shape
# Out:
# ((383, 25), (383, 25))

# %%
x_train_np = np.array(x_train)
y_train_np = np.array(y_train)
x_test_np = np.array(x_test)
y_test_np = np.array(y_test)

x_train_np = x_train_np.reshape(x_train_np.shape[0], x_train_np.shape[1], 1)
x_test_np = x_test_np.reshape(x_test_np.shape[0], x_test_np.shape[1], 1)
y_train_np = y_train_np.reshape(y_train_np.shape[0], 1)
y_test_np = y_test_np.reshape(y_test_np.shape[0], 1)

# %%
x_train_np.shape, y_train_np.shape, x_test_np.shape, y_test_np.shape
# Out:
# ((383, 25, 1), (383, 1), (96, 25, 1), (96, 1))

# %%
type(x_train_np), type(y_train_np), type(x_test_np), type(y_test_np)
# Out:
# (numpy.ndarray, numpy.ndarray, numpy.ndarray, numpy.ndarray)

# %%
x_train
# Out:
# array([[0.        , 0.        , 0.        , ..., 0.63333333, 0.18181818,
#         0.        ],
#        [0.        , 0.        , 0.17037037, ..., 0.6       , 0.27272727,
#         0.        ],
#        [0.        , 0.        , 0.36592593, ..., 0.6       , 0.36363636,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.00954074, ..., 0.43333333, 0.90909091,
#         1.        ],
#        [0.        , 0.        , 0.01345185, ..., 0.73333333, 0.90909091,
#         1.        ],
#        [0.        , 0.        , 0.16888889, ..., 0.76666667, 0.90909091,
#         1.        ]])

# %%
plt.figure(figsize=(16, 9))
plt.title('Training data - Expenses over time')
visual = df[df['account_id']==96].fillna(0)
visual.index = visual['date']
plt.plot(visual['amount'][:split], color='black')
plt.plot(visual['amount'][split:], color='green')
plt.xlabel('Date')
plt.ylabel('Expenses in HK$')
plt.savefig('predictions/96.png')
plt.show()

# %%
plt.figure(figsize=(16, 9))
plt.title('Training data - Expenses over time')
visual = df[df['account_id']==96].fillna(0)
visual.index = visual['date']
plt.plot(visual['amount'][split-100:split], color='black')
# plt.plot(visual['amount'][split:], color='green')
plt.xlabel('Date')
plt.ylabel('Expenses in HK$')
plt.savefig('predictions/96-2.png')
plt.show()

# %%
lstm_model=Sequential()
lstm_model.add(LSTM(units=50,return_sequences=True,input_shape=(x_train_np.shape[1], 1)))
lstm_model.add(LSTM(units=50))
lstm_model.add(Dense(1))
lstm_model.compile(loss='mean_squared_error',optimizer='adam')
lstm_model.summary()
# Out:
# 2023-03-30 06:14:51.876832: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 25, 50)            10400
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 30,651
# Trainable params: 30,651
# Non-trainable params: 0
# _________________________________________________________________

# %%
lstm_model.fit(x_train_np, y_train_np, batch_size=1, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 383/383 [==============================] - 4s 6ms/step - loss: 0.0302
# Epoch 2/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0290
# Epoch 3/100
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0288
# Epoch 4/100
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0289
# Epoch 5/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0287
# Epoch 6/100
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0287
# Epoch 7/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0285
# Epoch 8/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0289
# Epoch 9/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0285
# Epoch 10/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0287
# Epoch 11/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0286
# Epoch 12/100
# 383/383 [==============================] - 3s 8ms/step - loss: 0.0286
# Epoch 13/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0285
# Epoch 14/100
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0285
# Epoch 15/100
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0285
# Epoch 16/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0284
# Epoch 17/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0284
# Epoch 18/100
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0285
# Epoch 19/100
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0285
# Epoch 20/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0283
# Epoch 21/100
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0285
# Epoch 22/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0284
# Epoch 23/100
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0284
# Epoch 24/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0283
# Epoch 25/100
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0283
# Epoch 26/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0283
# Epoch 27/100
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0283
# Epoch 28/100
# 383/383 [==============================] - 2s 7ms/step - loss: 0.0282
# Epoch 29/100
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0283
# Epoch 30/100
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0284
# Epoch 31/100
# 383/383 [==============================] - 3s 8ms/step - loss: 0.0284
# Epoch 32/100
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0284
# Epoch 33/100
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0282
# Epoch 34/100
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0283
# Epoch 35/100
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0284
# Epoch 36/100
# 383/383 [==============================] - 3s 8ms/step - loss: 0.0283
# Epoch 37/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0283
# Epoch 38/100
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0283
# Epoch 39/100
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0282
# Epoch 40/100
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0282
# Epoch 41/100
# 383/383 [==============================] - 3s 9ms/step - loss: 0.0283
# Epoch 42/100
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0282
# Epoch 43/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0282
# Epoch 44/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0281
# Epoch 45/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0281
# Epoch 46/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0279
# Epoch 47/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0280
# Epoch 48/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0277
# Epoch 49/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0278
# Epoch 50/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0277
# Epoch 51/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0275
# Epoch 52/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0289
# Epoch 53/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0280
# Epoch 54/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0281
# Epoch 55/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0280
# Epoch 56/100
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0279
# Epoch 57/100
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0278
# Epoch 58/100
# 383/383 [==============================] - 4s 10ms/step - loss: 0.0282
# Epoch 59/100
# 383/383 [==============================] - 3s 8ms/step - loss: 0.0282
# Epoch 60/100
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0279
# Epoch 61/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0277
# Epoch 62/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0276
# Epoch 63/100
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0276
# Epoch 64/100
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0274
# Epoch 65/100
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0274
# Epoch 66/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0277
# Epoch 67/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0273
# Epoch 68/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0272
# Epoch 69/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0269
# Epoch 70/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0272
# Epoch 71/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0271
# Epoch 72/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0272
# Epoch 73/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0270
# Epoch 74/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0271
# Epoch 75/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0268
# Epoch 76/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0263
# Epoch 77/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0269
# Epoch 78/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0270
# Epoch 79/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0283
# Epoch 80/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0282
# Epoch 81/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0283
# Epoch 82/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0283
# Epoch 83/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0281
# Epoch 84/100
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0283
# Epoch 85/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0281
# Epoch 86/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0281
# Epoch 87/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0281
# Epoch 88/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0280
# Epoch 89/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0277
# Epoch 90/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0274
# Epoch 91/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0271
# Epoch 92/100
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0272
# Epoch 93/100
# 248/383 [==================>...........] - ETA: 0s - loss: 0.0307

# %%
y_predicted = lstm_model.predict(x_test_np)
# print(y_predicted)
print(y_predicted.shape)
y_predicted = scaler.inverse_transform(y_predicted)
# Out:
# (96, 1)

# %%
x_test_

# %%
y_test_transformed = scaler.inverse_transform(y_test_np)
print('Validation Root Mean Square Error (RMSE):', np.sqrt(mean_squared_error(y_test_transformed, y_predicted)))
# Out:
# Validation Root Mean Square Error (RMSE): 4230.825996478998

# %%
validation = actual.filter(['amount'])
validation['Prediction'] = y_predicted
validation
# Out:
#        amount   Prediction
# 0       5.256  3306.118896
# 1    2592.000   856.126282
# 2      16.560  2609.007568
# 3   18900.000  1637.476685
# 4     231.840  1145.099243
# ..        ...          ...
# 91    770.400   729.570374
# 92    231.840   207.806061
# 93    326.880   259.607117
# 94    396.000   306.659058
# 95   2700.000  1584.578003
#
# [96 rows x 2 columns]

# %%
actual = test.reset_index()
plt.figure(figsize=(16, 9))
plt.title('Testing data - Expenses over time')
plt.plot(actual['amount'], color='black')
plt.plot(y_predicted, color='green')
plt.xlabel('Date')
plt.ylabel('Expenses in HK$')
plt.show()

# %%
test
# Out:
#      index  trans_id  account_id  type     amount  last_trans_1  last_trans_2  \
# 383  13560     29714          96     1      5.256         5.256      7380.000
# 384  13561     29587          96     1   2592.000      2592.000         5.256
# 385  13562     29455          96     1     16.560        16.560      2592.000
# 386  13563     29798          96     1  18900.000     18900.000        16.560
# 387  13564     29527          96     1    231.840       231.840     18900.000
# ..     ...       ...         ...   ...        ...           ...           ...
# 474  13651     29395          96     1    770.400       770.400     21528.000
# 475  13652     29539          96     1    231.840       231.840       770.400
# 476  13653     29323          96     1    326.880       326.880       231.840
# 477  13654     29815          96     1    396.000       396.000       326.880
# 478  13655     29588          96     1   2700.000      2700.000       396.000
#
#      last_trans_3  last_trans_4  last_trans_5  ...  last_trans_15  \
# 383      4104.000       326.880       231.840  ...          5.256
# 384      7380.000      4104.000       326.880  ...         16.560
# 385         5.256      7380.000      4104.000  ...       6408.000
# 386      2592.000         5.256      7380.000  ...        231.840
# 387        16.560      2592.000         5.256  ...        770.400
# ..            ...           ...           ...  ...            ...
# 474      3780.000        16.560         5.256  ...        231.840
# 475     21528.000      3780.000        16.560  ...        770.400
# 476       770.400     21528.000      3780.000  ...        326.880
# 477       231.840       770.400     21528.000  ...       3456.000
# 478       326.880       231.840       770.400  ...          5.256
#
#      last_trans_16  last_trans_17  last_trans_18  last_trans_19  \
# 383       6048.000        326.880        770.400        231.840
# 384          5.256       6048.000        326.880        770.400
# 385         16.560          5.256       6048.000        326.880
# 386       6408.000         16.560          5.256       6048.000
# 387        231.840       6408.000         16.560          5.256
# ..             ...            ...            ...            ...
# 474         16.560       4212.000          5.256       5256.000
# 475        231.840         16.560       4212.000          5.256
# 476        770.400        231.840         16.560       4212.000
# 477        326.880        770.400        231.840         16.560
# 478       3456.000        326.880        770.400        231.840
#
#      last_trans_20  weekday  day  month  year
# 383         16.560        6   30     11  1997
# 384        231.840        2    3     12  1997
# 385        770.400        0    8     12  1997
# 386        326.880        3   11     12  1997
# 387       6048.000        3   11     12  1997
# ..             ...      ...  ...    ...   ...
# 474        326.880        4   11     12  1998
# 475       5256.000        4   11     12  1998
# 476          5.256        0   14     12  1998
# 477       4212.000        5   19     12  1998
# 478         16.560        0   21     12  1998
#
# [96 rows x 29 columns]

# %%
test.iloc[1]
# Out:
# index            13561.000
# trans_id         29587.000
# account_id          96.000
# type                 1.000
# amount            2592.000
# last_trans_1      2592.000
# last_trans_2         5.256
# last_trans_3      7380.000
# last_trans_4      4104.000
# last_trans_5       326.880
# last_trans_6       231.840
# last_trans_7       770.400
# last_trans_8        16.560
# last_trans_9         5.256
# last_trans_10     3636.000
# last_trans_11      326.880
# last_trans_12      770.400
# last_trans_13      231.840
# last_trans_14     6408.000
# last_trans_15       16.560
# last_trans_16        5.256
# last_trans_17     6048.000
# last_trans_18      326.880
# last_trans_19      770.400
# last_trans_20      231.840
# weekday              2.000
# day                  3.000
# month               12.000
# year              1997.000
# Name: 384, dtype: float64

# %%
import joblib

joblib.dump(lstm_model, 'lstm_model.pkl')
lr = joblib.load('lstm_model.pkl')
lstm_columns = list(x_t.columns)
joblib.dump(lstm_columns, 'lstm_columns.pkl')
# Out:
# 2023-03-29 22:37:20.735864: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://99bbd352-c036-4696-a19d-f93a4a035a9a/assets
# INFO:tensorflow:Assets written to: ram://99bbd352-c036-4696-a19d-f93a4a035a9a/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fa5f91c5e80> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fa5dde71640> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# ['lstm_columns.pkl']
